# %% [markdown]
# <a href="https://colab.research.google.com/github/nicks165/VectorDatabases/blob/main/Pinecone_evaluation_cohere_wiki_english_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cohere example

# %%
# !pip install -U cohere pinecone-client datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cohere in /usr/local/lib/python3.10/dist-packages (4.6.0)
# Requirement already satisfied: pinecone-client in /usr/local/lib/python3.10/dist-packages (2.2.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: backoff<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.2.1)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (3.8.4)
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.27.1)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (1.26.15)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (1.22.4)
# Requirement already satisfied: loguru>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (0.7.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.65.0)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.5.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.14.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (2.0.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0,>=3.0->cohere) (23.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->cohere) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->cohere) (2022.12.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)

# %%
import pinecone

def create_return_index():
  
  pinecone.init(api_key="199c7b9a-c651-4fb0-b5b9-4bc3f706b9b3",
              environment="us-east-1-aws")

  index_name = 'cohere-wiki-35m-en-cosine'
  dimension = 768
  
  # only create index if it doesn't exist
  if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        name=index_name,
        dimension=dimension,
        metric='cosine'
    )

  # now connect to the index
  index = pinecone.Index(index_name)

  return index

# %%
from IPython.utils.text import string
import time

def upsert_one_record(index, co):

  # add 1 more record
  eText1 = "How are you WORLD?"

  ewMetadata = [{"text" : eText1, "views" : 600}]
  xq = co.embed(texts=[eText1], model='multilingual-22-12').embeddings
  newRecords = zip([uuid.uuid4().hex], 
              xq,
              ewMetadata
              )

  start_time = time.time() 
  index.upsert(vectors=newRecords)

  print("Updated with one Record and Time taken --- %s seconds ---" % (time.time() - start_time))

  # check number of records in the index
  #index.describe_index_stats()

# %%
import numpy

def issue_measure_query_time(index, co):

  query1 = "What was the cause of the major recession in the early 20th century?"
  query2 = "Where is Mount Everest?"
  query3 = "something else"

  queries = [query1, query2, query3]

  timeTakenList = []

  ## Issue 3 queries and take the average

  for i in range(0, 2):
    # create the query embedding
    nearVector = {
        "vector": co.embed(texts=queries, model='multilingual-22-12').embeddings[i]
    }

    query_start_time = time.time()

    res = index.query(nearVector['vector'], top_k=5)

    query_end_time = time.time()

    timeTakenList.append(query_end_time - query_start_time)

    print(" For query number {0}, time taken for search = {1} ".format(queries[i], timeTakenList[i]))

   # print(json.dumps(result, indent=4))
  
  averageTimeTaken = numpy.average(timeTakenList)
  print("Average time taken for search = {0} ".format(averageTimeTaken))

# %%
def conditional_search(index, co):
  
  query1 = "What was the cause of the major recession in the early 20th century?"
  query2 = "Where is Mount Everest?"
  query3 = "something else"

  queries = [query1, query2, query3]
  near_vectors = co.embed(texts=queries, model='multilingual-22-12').embeddings

  timeTakenList = []

  ## Issue 3 queries and take the average
  for i in range(0, 2):
    query_start_time = time.time()

    result = index.query(
              vector=near_vectors[i],
              filter={
                "views": {"$gt": 300}
                },
              top_k=5,
              include_metadata=True
              )

    query_end_time = time.time()

    timeTakenList.append(query_end_time - query_start_time)

    print(" For query number {0}, time taken for conditional search = {1} ".format(i+1, timeTakenList[i]))
  
  averageTimeTaken = numpy.average(timeTakenList)
  print("Average time taken for conditional search = {0} ".format(averageTimeTaken))

# %%
import time
import uuid

MAX_ENTRIES = 35000000
def upsert_db_measure(docs, doc_embeddings, index, batch_size, total_inserted):
  co = cohere.Client(f"o7lTEJeC1QHjU5I4Ee6U2I0m6l5wCOUPWqwoGM7H")  # Add your cohere API key from www.cohere.com

  # create a list of unique ids for each item to be inserted
  ids = [uuid.uuid4().hex for i in range(batch_size)]

  # create list of metadata dictionaries
  meta = [{'text': doc['text'], 'views' : doc["views"]} for doc in docs]
  
  # create list of (id, vector, metadata) tuples to be upserted
  to_upsert = list(zip(ids, doc_embeddings, meta))

  start_time = time.time()
  
  index.upsert(vectors=to_upsert)

  total_inserted += batch_size

  if(total_inserted in range(0, MAX_ENTRIES, 100000)):
      print(" For {0} entries, time taken for inserts = {1} ".format(total_inserted, time.time() - start_time))
      upsert_one_record(index, co)
      issue_measure_query_time(index, co)
      conditional_search(index, co)
      
  # let's view the index statistics
  #print("==========================================")
  #print(index.describe_index_stats())

  return total_inserted

# %%
def execute_test_query():

  co = cohere.Client(f"o7lTEJeC1QHjU5I4Ee6U2I0m6l5wCOUPWqwoGM7H")  # Add your cohere API key from www.cohere.com

  query1 = "What was the cause of the major recession in the early 20th century?"
  query2 = "Where is Mount Everest?"


  # create the query embedding
  xq = co.embed(texts=[query1], model='multilingual-22-12').embeddings

  query_start_time = time.time()

  # query, returning the top 5 most similar results
  res = index.query(xq, top_k=5, include_metadata=True)

  print(" For 1 query, time taken for search = {0} ".format(time.time() - query_start_time))

  for item in res:
    print(item)

# %%
from datasets import load_dataset
import torch
import cohere

# Create a generator that yields chunks of the dataset
def chunk_generator(dataset, chunk_size):
  for i in range(0, len(dataset), chunk_size):
    yield dataset[i:i + chunk_size]

def load_cohere_dataset():
   # bring dataset to disk in Arrow table format
  dataset = load_dataset(f"Cohere/wikipedia-22-12-en-embeddings", split="train")
  return dataset

def load_execute_workload(index, dataset):

  limit = -1 # keep -1 for all, else update to a positive number to limit

  chunk_size = 500 # size of batch upserts and items kept in memory

  max_docs_loaded = 99500

  start_time = time.time()
  docs = []
  doc_embeddings = []

  # Iterate over the chunks
  for chunk in chunk_generator(dataset, chunk_size):
    for i in range(0, chunk_size):
      docs.append({"text" : chunk["text"][i], "views" : chunk['views'][i]})
      doc_embeddings.append(chunk['emb'][i])

    max_docs_loaded = upsert_db_measure(docs, doc_embeddings, index, chunk_size, max_docs_loaded)
    
    # clear the lists because we want to re-use them for the next chunk
    docs.clear()
    doc_embeddings.clear()

    if (limit > 0 and max_docs_loaded == limit):
      break
  
  print ("succesfully executed workload for {0} entries with total time {1}"
    .format(max_docs_loaded, time.time() - start_time))

# %% [markdown]
# Loading a big dataset is expensive. Seperate this step so that executing and debugging the main functions would be simple

# %%
dataset = load_cohere_dataset()
# Out:
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/Cohere___parquet/Cohere--wikipedia-22-12-en-embeddings-735980cfcb568494/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %%
# Debugging code - to be deleted afterwards
#docs = []
#doc_embeddings = []
#for chunk in chunk_generator(dataset, 2):
#  for i in range(0,2):
#    docs.append({"text" : chunk["text"][i], "views" : chunk['views'][i]})
#    doc_embeddings.append(chunk['emb'][i])
#    print (chunk)

#  break
# Out:
# {'id': [0, 1], 'title': ['Deaths in 2022', 'YouTube'], 'text': ['The following notable deaths occurred in 2022. Names are reported under the date of death, in alphabetical order. A typical entry reports information in the following sequence:', 'YouTube is a global online video sharing and social media platform headquartered in San Bruno, California. It was launched on February 14, 2005, by Steve Chen, Chad Hurley, and Jawed Karim. It is owned by Google, and is the second most visited website, after Google Search. YouTube has more than 2.5 billion monthly users who collectively watch more than one billion hours of videos each day. , videos were being uploaded at a rate of more than 500 hours of content per minute.'], 'url': ['https://en.wikipedia.org/wiki?curid=69407798', 'https://en.wikipedia.org/wiki?curid=3524766'], 'wiki_id': [69407798, 3524766], 'views': [5674.44921875, 5409.56103515625], 'paragraph_id': [0, 0], 'langs': [38, 184], 'emb': [[0.2865696847438812, -0.03181683272123337, 0.06668472290039062, 0.03292645886540413, -0.008292825892567635, 0.16873490810394287, -0.0008463106933049858, -0.36077880859375, 0.33916592597961426, 0.3886975646018982, -0.41489771008491516, 0.20758016407489777, -0.11468425393104553, 0.3873162567615509, -0.26252424716949463, 0.007096240296959877, 0.24166066944599152, -0.24653761088848114, 0.060873936861753464, 0.23045268654823303, -0.029800616204738617, 0.5721306800842285, -0.051111623644828796, -0.09547730535268784, 0.1097082868218422, -0.059516504406929016, -0.053682904690504074, 0.23981636762619019, -0.33325839042663574, 0.3685816824436188, 0.18456950783729553, -0.05209290236234665, -0.006129484623670578, 0.5033777952194214, -0.5287379026412964, 0.5231741070747375, 0.022464150562882423, -0.04248378053307533, 0.3180341124534607, -0.11792317032814026, 0.07446788251399994, 0.24792802333831787, 0.20263631641864777, -0.017194697633385658, 0.3679729402065277, 0.3847752511501312, 0.1616753190755844, 0.04726771265268326, -0.03529544919729233, 0.44717246294021606, -0.3653179109096527, -0.16520369052886963, -0.28060752153396606, 0.024058140814304352, -0.6397897601127625, 0.4281712472438812, -0.1488940566778183, 0.7482781410217285, 0.09189224243164062, -0.09540678560733795, 0.1863720566034317, -0.20858603715896606, -0.226043701171875, -0.06464707106351852, 0.6534488201141357, 0.19247837364673615, 0.017971690744161606, 0.3398212492465973, 0.26752832531929016, 0.24325883388519287, -0.10399176180362701, 0.1764550507068634, 0.4089451730251312, 0.0306655615568161, -0.15218715369701385, -0.6105571389198303, -0.29428744316101074, -0.07567915320396423, 0.3454975187778473, -0.49481201171875, 0.30831044912338257, -0.1701166182756424, -0.3128437101840973, 0.43910619616508484, 0.0723465085029602, 0.10430587083101273, -0.02630760706961155, 0.20559410750865936, 0.186318039894104, 0.43119731545448303, 0.038021814078092575, -0.005857009440660477, 0.1899631917476654, 0.06277817487716675, -0.31845253705978394, 0.23126140236854553, 0.30986103415489197, 0.07724857330322266, 0.4150647521018982, -0.34802427887916565, 0.4107922911643982, -0.29168057441711426, -0.07067399471998215, 0.47547993063926697, 0.3326416015625, -0.41482704877853394, -0.24874064326286316, 0.36725014448165894, 0.02771618403494358, 0.07121174782514572, 0.13025584816932678, -0.34746670722961426, -0.19653159379959106, 0.1350276917219162, 0.08115813881158829, -0.3373188078403473, 0.08884590864181519, 0.037877071648836136, -0.47193989157676697, -0.8052657246589661, 0.20728664100170135, 0.3810938894748688, -0.09562081098556519, -0.34648212790489197, -0.13760937750339508, 0.254058837890625, 0.44279399514198303, -0.13041415810585022, 0.5964741110801697, 0.01040127407759428, 0.4383191466331482, 0.27013757824897766, 0.35238486528396606, 0.5644145607948303, 0.17955218255519867, 0.39865434169769287, 0.0858612209558487, -0.22568552196025848, 0.006601032335311174, -0.15003184974193573, -0.3203526437282562, 0.09198610484600067, 0.1569037139415741, 0.6418200135231018,  ...
# {'id': [0, 1], 'title': ['Deaths in 2022', 'YouTube'], 'text': ['The following notable deaths occurred in 2022. Names are reported under the date of death, in alphabetical order. A typical entry reports information in the following sequence:', 'YouTube is a global online video sharing and social media platform headquartered in San Bruno, California. It was launched on February 14, 2005, by Steve Chen, Chad Hurley, and Jawed Karim. It is owned by Google, and is the second most visited website, after Google Search. YouTube has more than 2.5 billion monthly users who collectively watch more than one billion hours of videos each day. , videos were being uploaded at a rate of more than 500 hours of content per minute.'], 'url': ['https://en.wikipedia.org/wiki?curid=69407798', 'https://en.wikipedia.org/wiki?curid=3524766'], 'wiki_id': [69407798, 3524766], 'views': [5674.44921875, 5409.56103515625], 'paragraph_id': [0, 0], 'langs': [38, 184], 'emb': [[0.2865696847438812, -0.03181683272123337, 0.06668472290039062, 0.03292645886540413, -0.008292825892567635, 0.16873490810394287, -0.0008463106933049858, -0.36077880859375, 0.33916592597961426, 0.3886975646018982, -0.41489771008491516, 0.20758016407489777, -0.11468425393104553, 0.3873162567615509, -0.26252424716949463, 0.007096240296959877, 0.24166066944599152, -0.24653761088848114, 0.060873936861753464, 0.23045268654823303, -0.029800616204738617, 0.5721306800842285, -0.051111623644828796, -0.09547730535268784, 0.1097082868218422, -0.059516504406929016, -0.053682904690504074, 0.23981636762619019, -0.33325839042663574, 0.3685816824436188, 0.18456950783729553, -0.05209290236234665, -0.006129484623670578, 0.5033777952194214, -0.5287379026412964, 0.5231741070747375, 0.022464150562882423, -0.04248378053307533, 0.3180341124534607, -0.11792317032814026, 0.07446788251399994, 0.24792802333831787, 0.20263631641864777, -0.017194697633385658, 0.3679729402065277, 0.3847752511501312, 0.1616753190755844, 0.04726771265268326, -0.03529544919729233, 0.44717246294021606, -0.3653179109096527, -0.16520369052886963, -0.28060752153396606, 0.024058140814304352, -0.6397897601127625, 0.4281712472438812, -0.1488940566778183, 0.7482781410217285, 0.09189224243164062, -0.09540678560733795, 0.1863720566034317, -0.20858603715896606, -0.226043701171875, -0.06464707106351852, 0.6534488201141357, 0.19247837364673615, 0.017971690744161606, 0.3398212492465973, 0.26752832531929016, 0.24325883388519287, -0.10399176180362701, 0.1764550507068634, 0.4089451730251312, 0.0306655615568161, -0.15218715369701385, -0.6105571389198303, -0.29428744316101074, -0.07567915320396423, 0.3454975187778473, -0.49481201171875, 0.30831044912338257, -0.1701166182756424, -0.3128437101840973, 0.43910619616508484, 0.0723465085029602, 0.10430587083101273, -0.02630760706961155, 0.20559410750865936, 0.186318039894104, 0.43119731545448303, 0.038021814078092575, -0.005857009440660477, 0.1899631917476654, 0.06277817487716675, -0.31845253705978394, 0.23126140236854553, 0.30986103415489197, 0.07724857330322266, 0.4150647521018982, -0.34802427887916565, 0.4107922911643982, -0.29168057441711426, -0.07067399471998215, 0.47547993063926697, 0.3326416015625, -0.41482704877853394, -0.24874064326286316, 0.36725014448165894, 0.02771618403494358, 0.07121174782514572, 0.13025584816932678, -0.34746670722961426, -0.19653159379959106, 0.1350276917219162, 0.08115813881158829, -0.3373188078403473, 0.08884590864181519, 0.037877071648836136, -0.47193989157676697, -0.8052657246589661, 0.20728664100170135, 0.3810938894748688, -0.09562081098556519, -0.34648212790489197, -0.13760937750339508, 0.254058837890625, 0.44279399514198303, -0.13041415810585022, 0.5964741110801697, 0.01040127407759428, 0.4383191466331482, 0.27013757824897766, 0.35238486528396606, 0.5644145607948303, 0.17955218255519867, 0.39865434169769287, 0.0858612209558487, -0.22568552196025848, 0.006601032335311174, -0.15003184974193573, -0.3203526437282562, 0.09198610484600067, 0.1569037139415741, 0.6418200135231018,  ...

# %% [markdown]
# Main workload function

# %%
# initialize Pinecone and create index
index = create_return_index()

#download dataset and execute workload
load_execute_workload(index, dataset)
# Out:
#  For 100000 entries, time taken for inserts = 1.7218303680419922
# Updated with one Record and Time taken --- 0.07794928550720215 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11041140556335449
#  For query number Where is Mount Everest?, time taken for search = 0.10236382484436035
# Average time taken for search = 0.10638761520385742
#  For query number 1, time taken for conditional search = 0.10869169235229492
#  For query number 2, time taken for conditional search = 0.10640072822570801
# Average time taken for conditional search = 0.10754621028900146
#  For 200000 entries, time taken for inserts = 1.0927934646606445
# Updated with one Record and Time taken --- 0.0810079574584961 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11175775527954102
#  For query number Where is Mount Everest?, time taken for search = 0.13853979110717773
# Average time taken for search = 0.12514877319335938
#  For query number 1, time taken for conditional search = 0.11328291893005371
#  For query number 2, time taken for conditional search = 0.1085665225982666
# Average time taken for conditional search = 0.11092472076416016
#  For 300000 entries, time taken for inserts = 1.126718282699585
# Updated with one Record and Time taken --- 0.0871422290802002 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.10614919662475586
#  For query number Where is Mount Everest?, time taken for search = 0.11511754989624023
# Average time taken for search = 0.11063337326049805
#  For query number 1, time taken for conditional search = 0.10957670211791992
#  For query number 2, time taken for conditional search = 0.10864901542663574
# Average time taken for conditional search = 0.10911285877227783
#  For 400000 entries, time taken for inserts = 1.0382506847381592
# Updated with one Record and Time taken --- 0.08660030364990234 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.10745477676391602
#  For query number Where is Mount Everest?, time taken for search = 0.11317825317382812
# Average time taken for search = 0.11031651496887207
#  For query number 1, time taken for conditional search = 0.11641049385070801
#  For query number 2, time taken for conditional search = 0.11402511596679688
# Average time taken for conditional search = 0.11521780490875244
#  For 500000 entries, time taken for inserts = 1.1484153270721436
# Updated with one Record and Time taken --- 0.09041357040405273 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1136479377746582
#  For query number Where is Mount Everest?, time taken for search = 0.11209821701049805
# Average time taken for search = 0.11287307739257812
#  For query number 1, time taken for conditional search = 0.11174273490905762
#  For query number 2, time taken for conditional search = 0.11261892318725586
# Average time taken for conditional search = 0.11218082904815674
#  For 600000 entries, time taken for inserts = 1.166344404220581
# Updated with one Record and Time taken --- 0.09211301803588867 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1085820198059082
#  For query number Where is Mount Everest?, time taken for search = 0.108856201171875
# Average time taken for search = 0.1087191104888916
#  For query number 1, time taken for conditional search = 0.11204767227172852
#  For query number 2, time taken for conditional search = 0.11034846305847168
# Average time taken for conditional search = 0.1111980676651001
#  For 700000 entries, time taken for inserts = 1.0805938243865967
# Updated with one Record and Time taken --- 0.09642767906188965 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11525583267211914
#  For query number Where is Mount Everest?, time taken for search = 0.10912156105041504
# Average time taken for search = 0.11218869686126709
#  For query number 1, time taken for conditional search = 0.11289072036743164
#  For query number 2, time taken for conditional search = 0.10919690132141113
# Average time taken for conditional search = 0.11104381084442139
#  For 800000 entries, time taken for inserts = 1.1530916690826416
# Updated with one Record and Time taken --- 0.09676003456115723 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12128162384033203
#  For query number Where is Mount Everest?, time taken for search = 0.10873651504516602
# Average time taken for search = 0.11500906944274902
#  For query number 1, time taken for conditional search = 0.11248350143432617
#  For query number 2, time taken for conditional search = 0.11329436302185059
# Average time taken for conditional search = 0.11288893222808838
#  For 900000 entries, time taken for inserts = 1.109701156616211
# Updated with one Record and Time taken --- 0.10017967224121094 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11131620407104492
#  For query number Where is Mount Everest?, time taken for search = 0.1096193790435791
# Average time taken for search = 0.11046779155731201
#  For query number 1, time taken for conditional search = 0.11535763740539551
#  For query number 2, time taken for conditional search = 0.11515235900878906
# Average time taken for conditional search = 0.11525499820709229
#  For 1000000 entries, time taken for inserts = 1.1613860130310059
# Updated with one Record and Time taken --- 0.10454773902893066 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1162872314453125
#  For query number Where is Mount Everest?, time taken for search = 0.10885167121887207
# Average time taken for search = 0.11256945133209229
#  For query number 1, time taken for conditional search = 0.1128702163696289
#  For query number 2, time taken for conditional search = 0.11179900169372559
# Average time taken for conditional search = 0.11233460903167725
#  For 1100000 entries, time taken for inserts = 1.1488640308380127
# Updated with one Record and Time taken --- 0.10698509216308594 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11188960075378418
#  For query number Where is Mount Everest?, time taken for search = 0.11542797088623047
# Average time taken for search = 0.11365878582000732
#  For query number 1, time taken for conditional search = 0.12021613121032715
#  For query number 2, time taken for conditional search = 0.11765646934509277
# Average time taken for conditional search = 0.11893630027770996
#  For 1200000 entries, time taken for inserts = 1.2418522834777832
# Updated with one Record and Time taken --- 0.11284613609313965 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11227750778198242
#  For query number Where is Mount Everest?, time taken for search = 0.11238336563110352
# Average time taken for search = 0.11233043670654297
#  For query number 1, time taken for conditional search = 0.11605334281921387
#  For query number 2, time taken for conditional search = 0.132033109664917
# Average time taken for conditional search = 0.12404322624206543
#  For 1300000 entries, time taken for inserts = 1.2042236328125
# Updated with one Record and Time taken --- 0.11430096626281738 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1174306869506836
#  For query number Where is Mount Everest?, time taken for search = 0.11348414421081543
# Average time taken for search = 0.11545741558074951
#  For query number 1, time taken for conditional search = 0.1169588565826416
#  For query number 2, time taken for conditional search = 0.11501359939575195
# Average time taken for conditional search = 0.11598622798919678
#  For 1400000 entries, time taken for inserts = 1.2224986553192139
# Updated with one Record and Time taken --- 0.11419272422790527 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11463284492492676
#  For query number Where is Mount Everest?, time taken for search = 0.11792755126953125
# Average time taken for search = 0.116280198097229
#  For query number 1, time taken for conditional search = 0.11704349517822266
#  For query number 2, time taken for conditional search = 0.11452317237854004
# Average time taken for conditional search = 0.11578333377838135
#  For 1500000 entries, time taken for inserts = 1.1410295963287354
# Updated with one Record and Time taken --- 0.11780238151550293 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1160895824432373
#  For query number Where is Mount Everest?, time taken for search = 0.11128616333007812
# Average time taken for search = 0.11368787288665771
#  For query number 1, time taken for conditional search = 0.1165306568145752
#  For query number 2, time taken for conditional search = 0.11696076393127441
# Average time taken for conditional search = 0.1167457103729248
#  For 1600000 entries, time taken for inserts = 1.7389941215515137
# Updated with one Record and Time taken --- 0.1201162338256836 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11574745178222656
#  For query number Where is Mount Everest?, time taken for search = 0.11867547035217285
# Average time taken for search = 0.11721146106719971
#  For query number 1, time taken for conditional search = 0.12004351615905762
#  For query number 2, time taken for conditional search = 0.11653447151184082
# Average time taken for conditional search = 0.11828899383544922
#  For 1700000 entries, time taken for inserts = 1.1772019863128662
# Updated with one Record and Time taken --- 0.12363147735595703 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11521625518798828
#  For query number Where is Mount Everest?, time taken for search = 0.11463570594787598
# Average time taken for search = 0.11492598056793213
#  For query number 1, time taken for conditional search = 0.11755180358886719
#  For query number 2, time taken for conditional search = 0.11726784706115723
# Average time taken for conditional search = 0.11740982532501221
#  For 1800000 entries, time taken for inserts = 1.215754747390747
# Updated with one Record and Time taken --- 0.12535548210144043 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1164407730102539
#  For query number Where is Mount Everest?, time taken for search = 0.11952543258666992
# Average time taken for search = 0.11798310279846191
#  For query number 1, time taken for conditional search = 0.12345218658447266
#  For query number 2, time taken for conditional search = 0.11566448211669922
# Average time taken for conditional search = 0.11955833435058594
#  For 1900000 entries, time taken for inserts = 1.2102293968200684
# Updated with one Record and Time taken --- 0.1340641975402832 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11516237258911133
#  For query number Where is Mount Everest?, time taken for search = 0.11494278907775879
# Average time taken for search = 0.11505258083343506
#  For query number 1, time taken for conditional search = 0.12013077735900879
#  For query number 2, time taken for conditional search = 0.11765766143798828
# Average time taken for conditional search = 0.11889421939849854
#  For 2000000 entries, time taken for inserts = 1.2467272281646729
# Updated with one Record and Time taken --- 0.13695263862609863 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11594247817993164
#  For query number Where is Mount Everest?, time taken for search = 0.11889433860778809
# Average time taken for search = 0.11741840839385986
#  For query number 1, time taken for conditional search = 0.11732792854309082
#  For query number 2, time taken for conditional search = 0.11873483657836914
# Average time taken for conditional search = 0.11803138256072998
#  For 2100000 entries, time taken for inserts = 1.2291285991668701
# Updated with one Record and Time taken --- 0.15045475959777832 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12028169631958008
#  For query number Where is Mount Everest?, time taken for search = 0.11420869827270508
# Average time taken for search = 0.11724519729614258
#  For query number 1, time taken for conditional search = 0.11954236030578613
#  For query number 2, time taken for conditional search = 0.11813068389892578
# Average time taken for conditional search = 0.11883652210235596
#  For 2200000 entries, time taken for inserts = 1.1843023300170898
# Updated with one Record and Time taken --- 0.14171123504638672 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12176942825317383
#  For query number Where is Mount Everest?, time taken for search = 0.11796259880065918
# Average time taken for search = 0.1198660135269165
#  For query number 1, time taken for conditional search = 0.12038493156433105
#  For query number 2, time taken for conditional search = 0.11938810348510742
# Average time taken for conditional search = 0.11988651752471924
#  For 2300000 entries, time taken for inserts = 1.5991811752319336
# Updated with one Record and Time taken --- 0.14417624473571777 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12217521667480469
#  For query number Where is Mount Everest?, time taken for search = 0.11554980278015137
# Average time taken for search = 0.11886250972747803
#  For query number 1, time taken for conditional search = 0.12137150764465332
#  For query number 2, time taken for conditional search = 0.11734223365783691
# Average time taken for conditional search = 0.11935687065124512
#  For 2400000 entries, time taken for inserts = 1.255723237991333
# Updated with one Record and Time taken --- 0.14811944961547852 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11997389793395996
#  For query number Where is Mount Everest?, time taken for search = 0.12168622016906738
# Average time taken for search = 0.12083005905151367
#  For query number 1, time taken for conditional search = 0.12183189392089844
#  For query number 2, time taken for conditional search = 0.12467360496520996
# Average time taken for conditional search = 0.1232527494430542
#  For 2500000 entries, time taken for inserts = 1.2418842315673828
# Updated with one Record and Time taken --- 0.14894938468933105 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12242650985717773
#  For query number Where is Mount Everest?, time taken for search = 0.12382817268371582
# Average time taken for search = 0.12312734127044678
#  For query number 1, time taken for conditional search = 0.12090253829956055
#  For query number 2, time taken for conditional search = 0.12018084526062012
# Average time taken for conditional search = 0.12054169178009033
#  For 2600000 entries, time taken for inserts = 1.2428312301635742
# Updated with one Record and Time taken --- 0.15175795555114746 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13551783561706543
#  For query number Where is Mount Everest?, time taken for search = 0.12444138526916504
# Average time taken for search = 0.12997961044311523
#  For query number 1, time taken for conditional search = 0.12379574775695801
#  For query number 2, time taken for conditional search = 0.12543368339538574
# Average time taken for conditional search = 0.12461471557617188
#  For 2700000 entries, time taken for inserts = 1.2740051746368408
# Updated with one Record and Time taken --- 0.15617156028747559 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12047648429870605
#  For query number Where is Mount Everest?, time taken for search = 0.12107634544372559
# Average time taken for search = 0.12077641487121582
#  For query number 1, time taken for conditional search = 0.12971067428588867
#  For query number 2, time taken for conditional search = 0.12367534637451172
# Average time taken for conditional search = 0.1266930103302002
#  For 2800000 entries, time taken for inserts = 1.2337069511413574
# Updated with one Record and Time taken --- 0.1571063995361328 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.11839556694030762
#  For query number Where is Mount Everest?, time taken for search = 0.11904239654541016
# Average time taken for search = 0.11871898174285889
#  For query number 1, time taken for conditional search = 0.12598228454589844
#  For query number 2, time taken for conditional search = 0.12231898307800293
# Average time taken for conditional search = 0.12415063381195068
#  For 2900000 entries, time taken for inserts = 1.2289345264434814
# Updated with one Record and Time taken --- 0.17450404167175293 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12188577651977539
#  For query number Where is Mount Everest?, time taken for search = 0.12022542953491211
# Average time taken for search = 0.12105560302734375
#  For query number 1, time taken for conditional search = 0.15145206451416016
#  For query number 2, time taken for conditional search = 0.12190437316894531
# Average time taken for conditional search = 0.13667821884155273
#  For 3000000 entries, time taken for inserts = 1.2710886001586914
# Updated with one Record and Time taken --- 0.16274189949035645 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12137293815612793
#  For query number Where is Mount Everest?, time taken for search = 0.12028288841247559
# Average time taken for search = 0.12082791328430176
#  For query number 1, time taken for conditional search = 0.12570452690124512
#  For query number 2, time taken for conditional search = 0.12233424186706543
# Average time taken for conditional search = 0.12401938438415527
#  For 3100000 entries, time taken for inserts = 1.2614171504974365
# Updated with one Record and Time taken --- 0.17132568359375 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12462401390075684
#  For query number Where is Mount Everest?, time taken for search = 0.12345385551452637
# Average time taken for search = 0.1240389347076416
#  For query number 1, time taken for conditional search = 0.12745428085327148
#  For query number 2, time taken for conditional search = 0.1264815330505371
# Average time taken for conditional search = 0.1269679069519043
#  For 3200000 entries, time taken for inserts = 1.3801169395446777
# Updated with one Record and Time taken --- 0.17116332054138184 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.15069985389709473
#  For query number Where is Mount Everest?, time taken for search = 0.1284952163696289
# Average time taken for search = 0.13959753513336182
#  For query number 1, time taken for conditional search = 0.1308901309967041
#  For query number 2, time taken for conditional search = 0.1300668716430664
# Average time taken for conditional search = 0.13047850131988525
#  For 3300000 entries, time taken for inserts = 1.4037489891052246
# Updated with one Record and Time taken --- 0.17414212226867676 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12984466552734375
#  For query number Where is Mount Everest?, time taken for search = 0.13064002990722656
# Average time taken for search = 0.13024234771728516
#  For query number 1, time taken for conditional search = 0.13467144966125488
#  For query number 2, time taken for conditional search = 0.12908387184143066
# Average time taken for conditional search = 0.13187766075134277
#  For 3400000 entries, time taken for inserts = 1.2690777778625488
# Updated with one Record and Time taken --- 0.17904067039489746 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12430405616760254
#  For query number Where is Mount Everest?, time taken for search = 0.12691688537597656
# Average time taken for search = 0.12561047077178955
#  For query number 1, time taken for conditional search = 0.1284022331237793
#  For query number 2, time taken for conditional search = 0.12788605690002441
# Average time taken for conditional search = 0.12814414501190186
#  For 3500000 entries, time taken for inserts = 1.2922844886779785
# Updated with one Record and Time taken --- 0.17905902862548828 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12588119506835938
#  For query number Where is Mount Everest?, time taken for search = 0.12907028198242188
# Average time taken for search = 0.12747573852539062
#  For query number 1, time taken for conditional search = 0.13211607933044434
#  For query number 2, time taken for conditional search = 0.12965178489685059
# Average time taken for conditional search = 0.13088393211364746
#  For 3600000 entries, time taken for inserts = 1.283499002456665
# Updated with one Record and Time taken --- 0.1860365867614746 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12836623191833496
#  For query number Where is Mount Everest?, time taken for search = 0.1264667510986328
# Average time taken for search = 0.1274164915084839
#  For query number 1, time taken for conditional search = 0.13137531280517578
#  For query number 2, time taken for conditional search = 0.1296091079711914
# Average time taken for conditional search = 0.1304922103881836
#  For 3700000 entries, time taken for inserts = 1.2995939254760742
# Updated with one Record and Time taken --- 0.19641971588134766 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14617180824279785
#  For query number Where is Mount Everest?, time taken for search = 0.12608551979064941
# Average time taken for search = 0.13612866401672363
#  For query number 1, time taken for conditional search = 0.13051915168762207
#  For query number 2, time taken for conditional search = 0.12833428382873535
# Average time taken for conditional search = 0.1294267177581787
#  For 3800000 entries, time taken for inserts = 1.2893576622009277
# Updated with one Record and Time taken --- 0.199293851852417 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13028955459594727
#  For query number Where is Mount Everest?, time taken for search = 0.1269679069519043
# Average time taken for search = 0.12862873077392578
#  For query number 1, time taken for conditional search = 0.13573169708251953
#  For query number 2, time taken for conditional search = 0.13451576232910156
# Average time taken for conditional search = 0.13512372970581055
#  For 3900000 entries, time taken for inserts = 1.3253023624420166
# Updated with one Record and Time taken --- 0.2596771717071533 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1300973892211914
#  For query number Where is Mount Everest?, time taken for search = 0.12771129608154297
# Average time taken for search = 0.1289043426513672
#  For query number 1, time taken for conditional search = 0.13356971740722656
#  For query number 2, time taken for conditional search = 0.13395261764526367
# Average time taken for conditional search = 0.13376116752624512
#  For 4000000 entries, time taken for inserts = 1.30033278465271
# Updated with one Record and Time taken --- 0.20159411430358887 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1269688606262207
#  For query number Where is Mount Everest?, time taken for search = 0.1282031536102295
# Average time taken for search = 0.1275860071182251
#  For query number 1, time taken for conditional search = 0.13801002502441406
#  For query number 2, time taken for conditional search = 0.13495254516601562
# Average time taken for conditional search = 0.13648128509521484
#  For 4100000 entries, time taken for inserts = 1.2910783290863037
# Updated with one Record and Time taken --- 0.21169662475585938 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12752962112426758
#  For query number Where is Mount Everest?, time taken for search = 0.16719317436218262
# Average time taken for search = 0.1473613977432251
#  For query number 1, time taken for conditional search = 0.13388514518737793
#  For query number 2, time taken for conditional search = 0.13194823265075684
# Average time taken for conditional search = 0.13291668891906738
#  For 4200000 entries, time taken for inserts = 1.3356478214263916
# Updated with one Record and Time taken --- 0.20902466773986816 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12097287178039551
#  For query number Where is Mount Everest?, time taken for search = 0.12743711471557617
# Average time taken for search = 0.12420499324798584
#  For query number 1, time taken for conditional search = 0.13400816917419434
#  For query number 2, time taken for conditional search = 0.13166093826293945
# Average time taken for conditional search = 0.1328345537185669
#  For 4300000 entries, time taken for inserts = 1.3354337215423584
# Updated with one Record and Time taken --- 0.21330928802490234 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13134336471557617
#  For query number Where is Mount Everest?, time taken for search = 0.12707209587097168
# Average time taken for search = 0.12920773029327393
#  For query number 1, time taken for conditional search = 0.13312983512878418
#  For query number 2, time taken for conditional search = 0.131103515625
# Average time taken for conditional search = 0.1321166753768921
#  For 4400000 entries, time taken for inserts = 1.3888609409332275
# Updated with one Record and Time taken --- 0.22399258613586426 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12885761260986328
#  For query number Where is Mount Everest?, time taken for search = 0.13325858116149902
# Average time taken for search = 0.13105809688568115
#  For query number 1, time taken for conditional search = 0.1348714828491211
#  For query number 2, time taken for conditional search = 0.13369989395141602
# Average time taken for conditional search = 0.13428568840026855
#  For 4500000 entries, time taken for inserts = 1.3412673473358154
# Updated with one Record and Time taken --- 0.23550939559936523 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1330113410949707
#  For query number Where is Mount Everest?, time taken for search = 0.12965106964111328
# Average time taken for search = 0.131331205368042
#  For query number 1, time taken for conditional search = 0.13464808464050293
#  For query number 2, time taken for conditional search = 0.13249874114990234
# Average time taken for conditional search = 0.13357341289520264
#  For 4600000 entries, time taken for inserts = 1.3387563228607178
# Updated with one Record and Time taken --- 0.22132587432861328 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.3251149654388428
#  For query number Where is Mount Everest?, time taken for search = 0.13080215454101562
# Average time taken for search = 0.2279585599899292
#  For query number 1, time taken for conditional search = 0.13627290725708008
#  For query number 2, time taken for conditional search = 0.1354386806488037
# Average time taken for conditional search = 0.1358557939529419
#  For 4700000 entries, time taken for inserts = 1.3617002964019775
# Updated with one Record and Time taken --- 0.22606754302978516 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14251375198364258
#  For query number Where is Mount Everest?, time taken for search = 0.12974762916564941
# Average time taken for search = 0.136130690574646
#  For query number 1, time taken for conditional search = 0.1619570255279541
#  For query number 2, time taken for conditional search = 0.1329333782196045
# Average time taken for conditional search = 0.1474452018737793
#  For 4800000 entries, time taken for inserts = 1.2934901714324951
# Updated with one Record and Time taken --- 0.22881317138671875 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1360616683959961
#  For query number Where is Mount Everest?, time taken for search = 0.13553166389465332
# Average time taken for search = 0.1357966661453247
#  For query number 1, time taken for conditional search = 0.13970232009887695
#  For query number 2, time taken for conditional search = 0.135498046875
# Average time taken for conditional search = 0.13760018348693848
#  For 4900000 entries, time taken for inserts = 1.3511061668395996
# Updated with one Record and Time taken --- 0.22669672966003418 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13114619255065918
#  For query number Where is Mount Everest?, time taken for search = 0.1324148178100586
# Average time taken for search = 0.1317805051803589
#  For query number 1, time taken for conditional search = 0.1364147663116455
#  For query number 2, time taken for conditional search = 0.13861489295959473
# Average time taken for conditional search = 0.13751482963562012
#  For 5000000 entries, time taken for inserts = 1.4981157779693604
# Updated with one Record and Time taken --- 0.22855091094970703 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.16997265815734863
#  For query number Where is Mount Everest?, time taken for search = 0.13574457168579102
# Average time taken for search = 0.15285861492156982
#  For query number 1, time taken for conditional search = 0.13672947883605957
#  For query number 2, time taken for conditional search = 0.1350386142730713
# Average time taken for conditional search = 0.13588404655456543
#  For 5100000 entries, time taken for inserts = 1.3186240196228027
# Updated with one Record and Time taken --- 0.23873209953308105 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13612127304077148
#  For query number Where is Mount Everest?, time taken for search = 0.14166831970214844
# Average time taken for search = 0.13889479637145996
#  For query number 1, time taken for conditional search = 0.13499832153320312
#  For query number 2, time taken for conditional search = 0.13596844673156738
# Average time taken for conditional search = 0.13548338413238525
#  For 5200000 entries, time taken for inserts = 1.3429033756256104
# Updated with one Record and Time taken --- 0.23891830444335938 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14004731178283691
#  For query number Where is Mount Everest?, time taken for search = 0.13301324844360352
# Average time taken for search = 0.13653028011322021
#  For query number 1, time taken for conditional search = 0.13715267181396484
#  For query number 2, time taken for conditional search = 0.13600587844848633
# Average time taken for conditional search = 0.13657927513122559
#  For 5300000 entries, time taken for inserts = 1.3627090454101562
# Updated with one Record and Time taken --- 0.24451804161071777 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.12846660614013672
#  For query number Where is Mount Everest?, time taken for search = 0.12766599655151367
# Average time taken for search = 0.1280663013458252
#  For query number 1, time taken for conditional search = 0.14581823348999023
#  For query number 2, time taken for conditional search = 0.1307528018951416
# Average time taken for conditional search = 0.13828551769256592
#  For 5400000 entries, time taken for inserts = 1.3437590599060059
# Updated with one Record and Time taken --- 0.2462315559387207 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13791275024414062
#  For query number Where is Mount Everest?, time taken for search = 0.13821864128112793
# Average time taken for search = 0.13806569576263428
#  For query number 1, time taken for conditional search = 0.14200854301452637
#  For query number 2, time taken for conditional search = 0.14348173141479492
# Average time taken for conditional search = 0.14274513721466064
#  For 5500000 entries, time taken for inserts = 1.289074182510376
# Updated with one Record and Time taken --- 0.24681711196899414 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13721776008605957
#  For query number Where is Mount Everest?, time taken for search = 0.13483905792236328
# Average time taken for search = 0.13602840900421143
#  For query number 1, time taken for conditional search = 0.13914704322814941
#  For query number 2, time taken for conditional search = 0.13753008842468262
# Average time taken for conditional search = 0.13833856582641602
#  For 5600000 entries, time taken for inserts = 1.3993043899536133
# Updated with one Record and Time taken --- 0.2902698516845703 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13594698905944824
#  For query number Where is Mount Everest?, time taken for search = 0.13538503646850586
# Average time taken for search = 0.13566601276397705
#  For query number 1, time taken for conditional search = 0.137742280960083
#  For query number 2, time taken for conditional search = 0.1366724967956543
# Average time taken for conditional search = 0.13720738887786865
#  For 5700000 entries, time taken for inserts = 1.3935503959655762
# Updated with one Record and Time taken --- 0.3090384006500244 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13520216941833496
#  For query number Where is Mount Everest?, time taken for search = 0.13465356826782227
# Average time taken for search = 0.1349278688430786
#  For query number 1, time taken for conditional search = 0.13933253288269043
#  For query number 2, time taken for conditional search = 0.13828778266906738
# Average time taken for conditional search = 0.1388101577758789
#  For 5800000 entries, time taken for inserts = 1.3420791625976562
# Updated with one Record and Time taken --- 0.2545933723449707 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13710713386535645
#  For query number Where is Mount Everest?, time taken for search = 0.14054608345031738
# Average time taken for search = 0.13882660865783691
#  For query number 1, time taken for conditional search = 0.1424105167388916
#  For query number 2, time taken for conditional search = 0.14040422439575195
# Average time taken for conditional search = 0.14140737056732178
#  For 5900000 entries, time taken for inserts = 1.389392375946045
# Updated with one Record and Time taken --- 0.5089817047119141 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14596962928771973
#  For query number Where is Mount Everest?, time taken for search = 0.13685345649719238
# Average time taken for search = 0.14141154289245605
#  For query number 1, time taken for conditional search = 0.1426236629486084
#  For query number 2, time taken for conditional search = 0.15530014038085938
# Average time taken for conditional search = 0.1489619016647339
#  For 6000000 entries, time taken for inserts = 1.3711891174316406
# Updated with one Record and Time taken --- 0.26047253608703613 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13441920280456543
#  For query number Where is Mount Everest?, time taken for search = 0.1395576000213623
# Average time taken for search = 0.13698840141296387
#  For query number 1, time taken for conditional search = 0.14305973052978516
#  For query number 2, time taken for conditional search = 0.16169142723083496
# Average time taken for conditional search = 0.15237557888031006
#  For 6100000 entries, time taken for inserts = 1.423100233078003
# Updated with one Record and Time taken --- 0.2681407928466797 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1380157470703125
#  For query number Where is Mount Everest?, time taken for search = 0.13715362548828125
# Average time taken for search = 0.13758468627929688
#  For query number 1, time taken for conditional search = 0.14827322959899902
#  For query number 2, time taken for conditional search = 0.1430220603942871
# Average time taken for conditional search = 0.14564764499664307
#  For 6200000 entries, time taken for inserts = 1.4278419017791748
# Updated with one Record and Time taken --- 0.2668895721435547 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1376793384552002
#  For query number Where is Mount Everest?, time taken for search = 0.14257001876831055
# Average time taken for search = 0.14012467861175537
#  For query number 1, time taken for conditional search = 0.14551639556884766
#  For query number 2, time taken for conditional search = 0.14195609092712402
# Average time taken for conditional search = 0.14373624324798584
#  For 6300000 entries, time taken for inserts = 1.4067320823669434
# Updated with one Record and Time taken --- 0.27298831939697266 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14255499839782715
#  For query number Where is Mount Everest?, time taken for search = 0.13826680183410645
# Average time taken for search = 0.1404109001159668
#  For query number 1, time taken for conditional search = 0.18115973472595215
#  For query number 2, time taken for conditional search = 0.14205503463745117
# Average time taken for conditional search = 0.16160738468170166
#  For 6400000 entries, time taken for inserts = 1.4285788536071777
# Updated with one Record and Time taken --- 0.2719099521636963 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13677501678466797
#  For query number Where is Mount Everest?, time taken for search = 0.13690543174743652
# Average time taken for search = 0.13684022426605225
#  For query number 1, time taken for conditional search = 0.14337611198425293
#  For query number 2, time taken for conditional search = 0.14407825469970703
# Average time taken for conditional search = 0.14372718334197998
#  For 6500000 entries, time taken for inserts = 1.3532803058624268
# Updated with one Record and Time taken --- 0.27744054794311523 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.13922762870788574
#  For query number Where is Mount Everest?, time taken for search = 0.1399095058441162
# Average time taken for search = 0.13956856727600098
#  For query number 1, time taken for conditional search = 0.1437702178955078
#  For query number 2, time taken for conditional search = 0.1447746753692627
# Average time taken for conditional search = 0.14427244663238525
#  For 6600000 entries, time taken for inserts = 1.3834760189056396
# Updated with one Record and Time taken --- 0.4618046283721924 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.2915377616882324
#  For query number Where is Mount Everest?, time taken for search = 0.14336705207824707
# Average time taken for search = 0.21745240688323975
#  For query number 1, time taken for conditional search = 0.14859914779663086
#  For query number 2, time taken for conditional search = 0.14411282539367676
# Average time taken for conditional search = 0.1463559865951538
#  For 6700000 entries, time taken for inserts = 1.4078888893127441
# Updated with one Record and Time taken --- 0.2801649570465088 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14182043075561523
#  For query number Where is Mount Everest?, time taken for search = 0.13921236991882324
# Average time taken for search = 0.14051640033721924
#  For query number 1, time taken for conditional search = 0.14433908462524414
#  For query number 2, time taken for conditional search = 0.14365386962890625
# Average time taken for conditional search = 0.1439964771270752
#  For 6800000 entries, time taken for inserts = 1.4222362041473389
# Updated with one Record and Time taken --- 0.28452396392822266 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14209985733032227
#  For query number Where is Mount Everest?, time taken for search = 0.14136624336242676
# Average time taken for search = 0.1417330503463745
#  For query number 1, time taken for conditional search = 0.14716672897338867
#  For query number 2, time taken for conditional search = 0.165053129196167
# Average time taken for conditional search = 0.15610992908477783
#  For 6900000 entries, time taken for inserts = 1.3769359588623047
# Updated with one Record and Time taken --- 0.3173205852508545 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14361929893493652
#  For query number Where is Mount Everest?, time taken for search = 0.14078021049499512
# Average time taken for search = 0.14219975471496582
#  For query number 1, time taken for conditional search = 0.14795517921447754
#  For query number 2, time taken for conditional search = 0.14360427856445312
# Average time taken for conditional search = 0.14577972888946533
#  For 7000000 entries, time taken for inserts = 1.3866996765136719
# Updated with one Record and Time taken --- 0.2890603542327881 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14127278327941895
#  For query number Where is Mount Everest?, time taken for search = 0.13940906524658203
# Average time taken for search = 0.1403409242630005
#  For query number 1, time taken for conditional search = 0.14692425727844238
#  For query number 2, time taken for conditional search = 0.13007020950317383
# Average time taken for conditional search = 0.1384972333908081
#  For 7100000 entries, time taken for inserts = 1.5256426334381104
# Updated with one Record and Time taken --- 0.2949235439300537 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14271044731140137
#  For query number Where is Mount Everest?, time taken for search = 0.1416947841644287
# Average time taken for search = 0.14220261573791504
#  For query number 1, time taken for conditional search = 0.14633488655090332
#  For query number 2, time taken for conditional search = 0.14441227912902832
# Average time taken for conditional search = 0.14537358283996582
#  For 7200000 entries, time taken for inserts = 1.428983211517334
# Updated with one Record and Time taken --- 0.29352593421936035 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14068293571472168
#  For query number Where is Mount Everest?, time taken for search = 0.14339327812194824
# Average time taken for search = 0.14203810691833496
#  For query number 1, time taken for conditional search = 0.14701247215270996
#  For query number 2, time taken for conditional search = 0.15001535415649414
# Average time taken for conditional search = 0.14851391315460205
#  For 7300000 entries, time taken for inserts = 1.5006120204925537
# Updated with one Record and Time taken --- 0.30439114570617676 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.17697691917419434
#  For query number Where is Mount Everest?, time taken for search = 0.1474301815032959
# Average time taken for search = 0.16220355033874512
#  For query number 1, time taken for conditional search = 0.14660334587097168
#  For query number 2, time taken for conditional search = 0.1453859806060791
# Average time taken for conditional search = 0.1459946632385254
#  For 7400000 entries, time taken for inserts = 1.4412429332733154
# Updated with one Record and Time taken --- 0.3415858745574951 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14232850074768066
#  For query number Where is Mount Everest?, time taken for search = 0.14163565635681152
# Average time taken for search = 0.1419820785522461
#  For query number 1, time taken for conditional search = 0.1477646827697754
#  For query number 2, time taken for conditional search = 0.14606523513793945
# Average time taken for conditional search = 0.14691495895385742
#  For 7500000 entries, time taken for inserts = 1.4825501441955566
# Updated with one Record and Time taken --- 0.32856130599975586 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14303803443908691
#  For query number Where is Mount Everest?, time taken for search = 0.14913606643676758
# Average time taken for search = 0.14608705043792725
#  For query number 1, time taken for conditional search = 0.1533973217010498
#  For query number 2, time taken for conditional search = 0.15189194679260254
# Average time taken for conditional search = 0.15264463424682617
#  For 7600000 entries, time taken for inserts = 1.513303518295288
# Updated with one Record and Time taken --- 0.3329033851623535 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1422255039215088
#  For query number Where is Mount Everest?, time taken for search = 0.14886069297790527
# ...
#  For query number 2, time taken for conditional search = 0.1385197639465332
# Average time taken for conditional search = 0.1391124725341797
#  For 18500000 entries, time taken for inserts = 2.1924383640289307
# Updated with one Record and Time taken --- 0.7841293811798096 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.17054510116577148
#  For query number Where is Mount Everest?, time taken for search = 0.15058326721191406
# Average time taken for search = 0.16056418418884277
#  For query number 1, time taken for conditional search = 0.13795995712280273
#  For query number 2, time taken for conditional search = 0.13686394691467285
# Average time taken for conditional search = 0.1374119520187378
#  For 18600000 entries, time taken for inserts = 1.9871225357055664
# Updated with one Record and Time taken --- 0.7597801685333252 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.14597463607788086
#  For query number Where is Mount Everest?, time taken for search = 0.1836385726928711
# Average time taken for search = 0.16480660438537598
#  For query number 1, time taken for conditional search = 0.13747286796569824
#  For query number 2, time taken for conditional search = 0.1812593936920166
# Average time taken for conditional search = 0.15936613082885742
#  For 18700000 entries, time taken for inserts = 1.9982824325561523
# Updated with one Record and Time taken --- 0.8284649848937988 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.15167808532714844
#  For query number Where is Mount Everest?, time taken for search = 0.1477210521697998
# Average time taken for search = 0.14969956874847412
#  For query number 1, time taken for conditional search = 0.13699078559875488
#  For query number 2, time taken for conditional search = 0.1371316909790039
# Average time taken for conditional search = 0.1370612382888794
#  For 18800000 entries, time taken for inserts = 1.9972457885742188
# Updated with one Record and Time taken --- 0.7635748386383057 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.15581893920898438
#  For query number Where is Mount Everest?, time taken for search = 0.18415021896362305
# Average time taken for search = 0.1699845790863037
#  For query number 1, time taken for conditional search = 0.16606760025024414
#  For query number 2, time taken for conditional search = 0.16910409927368164
# Average time taken for conditional search = 0.1675858497619629
#  For 18900000 entries, time taken for inserts = 2.1026570796966553
# Updated with one Record and Time taken --- 0.8282051086425781 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.4165215492248535
#  For query number Where is Mount Everest?, time taken for search = 0.17372488975524902
# Average time taken for search = 0.29512321949005127
#  For query number 1, time taken for conditional search = 0.13969993591308594
#  For query number 2, time taken for conditional search = 0.16402697563171387
# Average time taken for conditional search = 0.1518634557723999
#  For 19000000 entries, time taken for inserts = 2.1104207038879395
# Updated with one Record and Time taken --- 0.7840614318847656 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.151106595993042
#  For query number Where is Mount Everest?, time taken for search = 0.15220260620117188
# Average time taken for search = 0.15165460109710693
#  For query number 1, time taken for conditional search = 0.14539813995361328
#  For query number 2, time taken for conditional search = 0.166046142578125
# Average time taken for conditional search = 0.15572214126586914
#  For 19100000 entries, time taken for inserts = 2.075366497039795
# Updated with one Record and Time taken --- 0.7966890335083008 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1712040901184082
#  For query number Where is Mount Everest?, time taken for search = 0.14592695236206055
# Average time taken for search = 0.15856552124023438
#  For query number 1, time taken for conditional search = 0.14185404777526855
#  For query number 2, time taken for conditional search = 0.16571426391601562
# Average time taken for conditional search = 0.1537841558456421
#  For 19200000 entries, time taken for inserts = 2.00189208984375
# Updated with one Record and Time taken --- 0.8076934814453125 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.18854427337646484
#  For query number Where is Mount Everest?, time taken for search = 0.2026805877685547
# Average time taken for search = 0.19561243057250977
#  For query number 1, time taken for conditional search = 0.1404857635498047
#  For query number 2, time taken for conditional search = 0.14174938201904297
# Average time taken for conditional search = 0.14111757278442383
#  For 19300000 entries, time taken for inserts = 2.04789662361145
# Updated with one Record and Time taken --- 0.8312978744506836 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.15242505073547363
#  For query number Where is Mount Everest?, time taken for search = 0.17129063606262207
# Average time taken for search = 0.16185784339904785
#  For query number 1, time taken for conditional search = 0.16527819633483887
#  For query number 2, time taken for conditional search = 0.15820097923278809
# Average time taken for conditional search = 0.16173958778381348
#  For 19400000 entries, time taken for inserts = 2.023460865020752
# Updated with one Record and Time taken --- 0.8003003597259521 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.18642878532409668
#  For query number Where is Mount Everest?, time taken for search = 0.17798972129821777
# Average time taken for search = 0.18220925331115723
#  For query number 1, time taken for conditional search = 0.17291784286499023
#  For query number 2, time taken for conditional search = 0.17221593856811523
# Average time taken for conditional search = 0.17256689071655273
#  For 19500000 entries, time taken for inserts = 2.038550615310669
# Updated with one Record and Time taken --- 0.8149950504302979 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.19506144523620605
#  For query number Where is Mount Everest?, time taken for search = 0.1756429672241211
# Average time taken for search = 0.18535220623016357
#  For query number 1, time taken for conditional search = 0.16611313819885254
#  For query number 2, time taken for conditional search = 0.13838815689086914
# Average time taken for conditional search = 0.15225064754486084
#  For 19600000 entries, time taken for inserts = 2.1702206134796143
# Updated with one Record and Time taken --- 0.7962112426757812 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.18074536323547363
#  For query number Where is Mount Everest?, time taken for search = 0.17374873161315918
# Average time taken for search = 0.1772470474243164
#  For query number 1, time taken for conditional search = 0.16829228401184082
#  For query number 2, time taken for conditional search = 0.1660139560699463
# Average time taken for conditional search = 0.16715312004089355
#  For 19700000 entries, time taken for inserts = 2.077871561050415
# Updated with one Record and Time taken --- 0.7777528762817383 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1507737636566162
#  For query number Where is Mount Everest?, time taken for search = 0.2116684913635254
# Average time taken for search = 0.1812211275100708
#  For query number 1, time taken for conditional search = 0.164506196975708
#  For query number 2, time taken for conditional search = 0.16916632652282715
# Average time taken for conditional search = 0.16683626174926758
#  For 19800000 entries, time taken for inserts = 2.1018455028533936
# Updated with one Record and Time taken --- 0.7977266311645508 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.15354108810424805
#  For query number Where is Mount Everest?, time taken for search = 0.1886458396911621
# Average time taken for search = 0.17109346389770508
#  For query number 1, time taken for conditional search = 0.1636197566986084
#  For query number 2, time taken for conditional search = 0.16421294212341309
# Average time taken for conditional search = 0.16391634941101074
#  For 19900000 entries, time taken for inserts = 2.0225789546966553
# Updated with one Record and Time taken --- 0.8281011581420898 seconds ---
#  For query number What was the cause of the major recession in the early 20th century?, time taken for search = 0.1831519603729248
#  For query number Where is Mount Everest?, time taken for search = 0.18345260620117188
# Average time taken for search = 0.18330228328704834
#  For query number 1, time taken for conditional search = 0.16169190406799316
#  For query number 2, time taken for conditional search = 0.13855719566345215
# Average time taken for conditional search = 0.15012454986572266
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# <ipython-input-68-5caace7215b5> in <cell line: 5>()
#       3
#       4 #download dataset and execute workload
# ----> 5 load_execute_workload(index, dataset)
#
# <ipython-input-62-ddc8d217aafc> in load_execute_workload(index, dataset)
#      31       doc_embeddings.append(chunk['emb'][i])
#      32
# ---> 33     max_docs_loaded = upsert_db_measure(docs, doc_embeddings, index, chunk_size, max_docs_loaded)
#      34
#      35     # clear the lists because we want to re-use them for the next chunk
#
# <ipython-input-64-57149d6f8031> in upsert_db_measure(docs, doc_embeddings, index, batch_size, total_inserted)
#      17   start_time = time.time()
#      18
# ---> 19   index.upsert(vectors=to_upsert)
#      20
#      21   total_inserted += batch_size
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/utils/error_handling.py in inner_func(*args, **kwargs)
#      15         Config.validate()  # raises exceptions in case of invalid config
#      16         try:
# ---> 17             return func(*args, **kwargs)
#      18         except MaxRetryError as e:
#      19             if isinstance(e.reason, ProtocolError):
#
# /usr/local/lib/python3.10/dist-packages/pinecone/index.py in upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     145
#     146         if batch_size is None:
# --> 147             return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     148
#     149         if not isinstance(batch_size, int) or batch_size <= 0:
#
# /usr/local/lib/python3.10/dist-packages/pinecone/index.py in _upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     229             raise ValueError(f"Invalid vector value passed: cannot interpret type {type(item)}")
#     230
# --> 231         return self._vector_api.upsert(
#     232             UpsertRequest(
#     233                 vectors=list(map(_vector_transform, vectors)),
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api_client.py in __call__(self, *args, **kwargs)
#     774
#     775         """
# --> 776         return self.callable(self, *args, **kwargs)
#     777
#     778     def call_with_http_info(self, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api/vector_operations_api.py in __upsert(self, upsert_request, **kwargs)
#     954             kwargs['upsert_request'] = \
#     955                 upsert_request
# --> 956             return self.call_with_http_info(**kwargs)
#     957
#     958         self.upsert = _Endpoint(
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api_client.py in call_with_http_info(self, **kwargs)
#     836             params['header']['Content-Type'] = header_list
#     837
# --> 838         return self.api_client.call_api(
#     839             self.settings['endpoint_path'], self.settings['http_method'],
#     840             params['path'],
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api_client.py in call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     411         """
#     412         if not async_req:
# --> 413             return self.__call_api(resource_path, method,
#     414                                    path_params, query_params, header_params,
#     415                                    body, post_params, files,
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     205         except ApiException as e:
#     206             e.body = e.body.decode('utf-8')
# --> 207             raise e
#     208
#     209         self.last_response = response_data
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api_client.py in __call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     198         try:
#     199             # perform request and return response
# --> 200             response_data = self.request(
#     201                 method, url, query_params=query_params, headers=header_params,
#     202                 post_params=post_params, body=body,
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/api_client.py in request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     457                                             body=body)
#     458         elif method == "POST":
# --> 459             return self.rest_client.POST(url,
#     460                                          query_params=query_params,
#     461                                          headers=headers,
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/rest.py in POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     269     def POST(self, url, headers=None, query_params=None, post_params=None,
#     270              body=None, _preload_content=True, _request_timeout=None):
# --> 271         return self.request("POST", url,
#     272                             headers=headers,
#     273                             query_params=query_params,
#
# /usr/local/lib/python3.10/dist-packages/pinecone/core/client/rest.py in request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     228                 raise ServiceException(http_resp=r)
#     229
# --> 230             raise ApiException(http_resp=r)
#     231
#     232         return r
#
# ApiException: (429)
# Reason: Too Many Requests
# HTTP response headers: HTTPHeaderDict({'content-type': 'application/json', 'date': 'Sun, 28 May 2023 15:58:17 GMT', 'x-envoy-upstream-service-time': '744', 'content-length': '70', 'server': 'envoy'})
# HTTP response body: {"code":8,"message":"index is full, cannot accept data.","details":[]}
